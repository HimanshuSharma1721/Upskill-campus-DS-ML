# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuSharma1721/Upskill-campus-DS-ML/blob/main/Prediction_of_Agriculture_crop_Production_in_India_%2C_Himanshu_sharma_upskill_campus_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/datafile.csv')
data
# Out:
#                    Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0                  Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1                 Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2        Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3                Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4           Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
# 5                Fruits    100.0     99.0     99.0     98.0    102.0    104.0
# 6                  Milk    100.0     97.0     98.0     98.0     98.0    112.0
# 7   Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# 8              Oilseeds    100.0     86.0     85.0     97.0    104.0    103.0
# 9            Sugarcane     100.0     96.0     91.0     87.0     80.0     81.0
# 10               Fibers    100.0     92.0     91.0     96.0    109.0    107.0
# ...

# %%
data.head()
# Out:
#              Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0            Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1           Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3          Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4     Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
#
#    2010-11  2011-12
# 0    117.0    110.0
# 1    120.0    108.0
# 2    122.0    136.0
# 3    137.0    129.0
# 4    128.0    115.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Crop     12 non-null     object
#  1   2004-05  12 non-null     float64
#  2   2005-06  12 non-null     float64
#  3   2006-07  12 non-null     float64
#  4   2007-08  12 non-null     float64
#  5   2008-09  12 non-null     float64
#  6   2009-10  12 non-null     float64
#  7   2010-11  12 non-null     float64
#  8   2011-12  12 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 1.0+ KB

# %%
data['2011-12'].hist()
# Out:
# <Axes: >

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': '2004-05'}>,
#         <Axes: title={'center': '2005-06'}>,
#         <Axes: title={'center': '2006-07'}>],
#        [<Axes: title={'center': '2007-08'}>,
#         <Axes: title={'center': '2008-09'}>,
#         <Axes: title={'center': '2009-10'}>],
#        [<Axes: title={'center': '2010-11'}>,
#         <Axes: title={'center': '2011-12'}>, <Axes: >]], dtype=object)

# %%
data['2010-11'].hist()
# Out:
# <Axes: >

# %%
data['2009-10'].hist()
# Out:
# <Axes: >

# %%
data['2006-07'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.boxplot (x='2009-10', y='2010-11',data=data)
# Out:
# <Axes: xlabel='2009-10', ylabel='2010-11'>

# %%
from pandas.io.formats.style import plt
# scatter plot 2013 data vs 2014 data
plt.scatter(data['2010-11'],data['2011-12'])
plt.show()

# %%
# line plot 2013 data vs 2014 data
plt.plot(data['2010-11'],data['2011-12'])
plt.show()

# %%
# import required modules
import matplotlib.pyplot as plt
from scipy import stats


# assign data
x = data['2010-11']
y = data['2011-12']


# linear regression 2010-11 data vs 2011-12 data
slope, intercept, r, p, std_err = stats.linregress(x, y)


# function to return slope
def myfunc(x):
	return slope * x + intercept


mymodel = list(map(myfunc, x))

# scatter
plt.scatter(x, y)

# plotting the data
plt.plot(x, mymodel)

# display the figure
plt.show()

# %%
# import required modules
import matplotlib.pyplot as plt
from scipy import stats


# assign data
x = data['2009-10']
y = data['2010-11']


# linear regression 2009-10 data vs 2010-11 data
slope, intercept, r, p, std_err = stats.linregress(x, y)


# function to return slope
def myfunc(x):
	return slope * x + intercept


mymodel = list(map(myfunc, x))

# scatter
plt.scatter(x, y)

# plotting the data
plt.plot(x, mymodel)

# display the figure
plt.show()

# %%
sns.heatmap(data.isnull(),cmap="coolwarm")
plt.show()
